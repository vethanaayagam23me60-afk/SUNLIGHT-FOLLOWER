# %% [markdown]
# <a href="https://colab.research.google.com/github/vethanaayagam23me60-afk/SUNLIGHT-FOLLOWER/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-genai

# %%
from google import genai

client = genai.Client(api_key="AIzaSyC0whTFFd6rPwtxVKgKRteyqRz-W1OAVVQ")

def generate_story(prompt):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=f"Write a short creative story about: {prompt}"
    )
    return response.text

topic = input("Enter your story idea: ")
story = generate_story(topic)

print("\nGenerated Story:\n")
print(story)
# Out:
# Enter your story idea: A lost dragon in a small town
#
# Generated Story:
#
# The silence of Willow Creek was typically broken only by the chirping of crickets, the rustle of leaves, or the distant lowing of Bessie the cow. So, when a sound like a hundred anvils falling onto a trampoline echoed through the valley just before dawn, Sheriff Brody nearly dropped his morning coffee.
#
# He found it in Mrs. Gable’s prize-winning rose garden. Not *in* the garden, exactly. *Sprawled* across it, crushing half a dozen hybrid tea roses under its colossal, moss-green flank. It was a dragon. A very, very large, very, very confused dragon.
#
# Its scales shimmered like polished jade, and its long neck was elegantly curved, ending in a head the size of a minivan, with eyes like ancient amber. A plume of smoky breath curled from its nostrils, smelling faintly of ozone and burnt sugar. It whimpered, a sound remarkably like a deflating hot air balloon, and blinked slowly.
#
# ...
